# %%
import pandas as pd
path= 'usa_hours.csv'
usa_hours = pd.read_csv(path)
df.head()
# Out:
#   STRUCTURE                                 STRUCTURE_ID  \
# 0  DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 1  DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 2  DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 3  DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 4  DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
#
#                                     STRUCTURE_NAME ACTION REF_AREA  \
# 0  Average annual hours actually worked per worker      I      USA
# 1  Average annual hours actually worked per worker      I      USA
# 2  Average annual hours actually worked per worker      I      USA
# 3  Average annual hours actually worked per worker      I      USA
# 4  Average annual hours actually worked per worker      I      USA
#
#   Reference area MEASURE       Measure UNIT_MEASURE  \
# 0  United States      HW  Hours worked       H_Y_PS
# 1  United States      HW  Hours worked       H_Y_PS
# 2  United States      HW  Hours worked       H_Y_PS
# ...

# %%
usa_hours.shape
# Out:
# (15, 40)

# %%
usa_hours.isna().sum()
# Out:
# STRUCTURE                    0
# STRUCTURE_ID                 0
# STRUCTURE_NAME               0
# ACTION                       0
# REF_AREA                     0
# Reference area               0
# MEASURE                      0
# Measure                      0
# UNIT_MEASURE                 0
# Unit of measure              0
# SEX                          0
# Sex                          0
# AGE                          0
# Age                          0
# LABOUR_FORCE_STATUS          0
# Labour force status          0
# WORK_PERIOD                  0
# Work period                  0
# HOURS_TYPE                   0
# Hours type                   0
# WORKER_STATUS                0
# Worker status                0
# WORK_TIME_ARNGMNT            0
# Working time arrangement     0
# AGGREGATION_OPERATION        0
# Aggregation operation        0
# HOUR_BANDS                   0
# Hour bands                   0
# JOB_COVERAGE                 0
# Job coverage                 0
# ...

# %%
usa_hours.dropna(axis=1, inplace=True)

# %%
import pandas as pd
path= 'mexico_hours.csv'
mexico_hours = pd.read_csv(path)
mexico_hours.head()
# Out:
#   STRUCTURE                                 STRUCTURE_ID  \
# 0  DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 1  DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 2  DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 3  DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 4  DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
#
#                                     STRUCTURE_NAME ACTION REF_AREA  \
# 0  Average annual hours actually worked per worker      I      MEX
# 1  Average annual hours actually worked per worker      I      MEX
# 2  Average annual hours actually worked per worker      I      MEX
# 3  Average annual hours actually worked per worker      I      MEX
# 4  Average annual hours actually worked per worker      I      MEX
#
#   Reference area MEASURE       Measure UNIT_MEASURE  \
# 0         Mexico      HW  Hours worked       H_Y_PS
# 1         Mexico      HW  Hours worked       H_Y_PS
# 2         Mexico      HW  Hours worked       H_Y_PS
# ...

# %%
mexico_hours.shape
# Out:
# (15, 40)

# %%
mexico_hours.isna().sum()
# Out:
# STRUCTURE                    0
# STRUCTURE_ID                 0
# STRUCTURE_NAME               0
# ACTION                       0
# REF_AREA                     0
# Reference area               0
# MEASURE                      0
# Measure                      0
# UNIT_MEASURE                 0
# Unit of measure              0
# SEX                          0
# Sex                          0
# AGE                          0
# Age                          0
# LABOUR_FORCE_STATUS          0
# Labour force status          0
# WORK_PERIOD                  0
# Work period                  0
# HOURS_TYPE                   0
# Hours type                   0
# WORKER_STATUS                0
# Worker status                0
# WORK_TIME_ARNGMNT            0
# Working time arrangement     0
# AGGREGATION_OPERATION        0
# Aggregation operation        0
# HOUR_BANDS                   0
# Hour bands                   0
# JOB_COVERAGE                 0
# Job coverage                 0
# ...

# %%
mexico_hours.dropna(axis=1, inplace=True)

# %%
# Load the CSVs
usa_hours = pd.read_csv("usa_hours.csv")
mexico_hours = pd.read_csv("mexico_hours.csv")

# Add a 'country' column to each
usa_hours['country'] = 'USA'
mexico_hours['country'] = 'Mexico'

# Concatenate the datasets
combined = pd.concat([usa_hours, mexico_hours], axis=0).reset_index(drop=True)

# %%
# Show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

combined  # this will display the full dataset including USA and Mexico
# Out:
#    STRUCTURE                                 STRUCTURE_ID  \
# 0   DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 1   DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 2   DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 3   DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 4   DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 5   DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 6   DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 7   DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 8   DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 9   DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 10  DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 11  DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 12  DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 13  DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 14  DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# ...

# %%
combined.isnull().sum()
# Out:
# STRUCTURE                    0
# STRUCTURE_ID                 0
# STRUCTURE_NAME               0
# ACTION                       0
# REF_AREA                     0
# Reference area               0
# MEASURE                      0
# Measure                      0
# UNIT_MEASURE                 0
# Unit of measure              0
# SEX                          0
# Sex                          0
# AGE                          0
# Age                          0
# LABOUR_FORCE_STATUS          0
# Labour force status          0
# WORK_PERIOD                  0
# Work period                  0
# HOURS_TYPE                   0
# Hours type                   0
# WORKER_STATUS                0
# Worker status                0
# WORK_TIME_ARNGMNT            0
# Working time arrangement     0
# AGGREGATION_OPERATION        0
# Aggregation operation        0
# HOUR_BANDS                   0
# Hour bands                   0
# JOB_COVERAGE                 0
# Job coverage                 0
# ...

# %%
combined = combined.dropna()  # drop rows with ANY missing value

# %%
combined.isnull().sum()
# Out:
# STRUCTURE                   0
# STRUCTURE_ID                0
# STRUCTURE_NAME              0
# ACTION                      0
# REF_AREA                    0
# Reference area              0
# MEASURE                     0
# Measure                     0
# UNIT_MEASURE                0
# Unit of measure             0
# SEX                         0
# Sex                         0
# AGE                         0
# Age                         0
# LABOUR_FORCE_STATUS         0
# Labour force status         0
# WORK_PERIOD                 0
# Work period                 0
# HOURS_TYPE                  0
# Hours type                  0
# WORKER_STATUS               0
# Worker status               0
# WORK_TIME_ARNGMNT           0
# Working time arrangement    0
# AGGREGATION_OPERATION       0
# Aggregation operation       0
# HOUR_BANDS                  0
# Hour bands                  0
# JOB_COVERAGE                0
# Job coverage                0
# TIME_PERIOD                 0
# ...

# %%
usa_hours = pd.read_csv("usa_hours.csv")
mexico_hours = pd.read_csv("mexico_hours.csv")

# %%
usa_hours['country'] = 'USA'
mexico_hours['country'] = 'Mexico'

# %%
combined = pd.concat([usa_hours, mexico_hours], axis=0).reset_index(drop=True)

# %%
combined.isnull().sum()
# Out:
# STRUCTURE                    0
# STRUCTURE_ID                 0
# STRUCTURE_NAME               0
# ACTION                       0
# REF_AREA                     0
# Reference area               0
# MEASURE                      0
# Measure                      0
# UNIT_MEASURE                 0
# Unit of measure              0
# SEX                          0
# Sex                          0
# AGE                          0
# Age                          0
# LABOUR_FORCE_STATUS          0
# Labour force status          0
# WORK_PERIOD                  0
# Work period                  0
# HOURS_TYPE                   0
# Hours type                   0
# WORKER_STATUS                0
# Worker status                0
# WORK_TIME_ARNGMNT            0
# Working time arrangement     0
# AGGREGATION_OPERATION        0
# Aggregation operation        0
# HOUR_BANDS                   0
# Hour bands                   0
# JOB_COVERAGE                 0
# Job coverage                 0
# ...

# %%
combined = pd.concat([usa_hours, mexico_hours], axis=0).reset_index(drop=True)
combined.isnull().sum()
# Out:
# STRUCTURE                    0
# STRUCTURE_ID                 0
# STRUCTURE_NAME               0
# ACTION                       0
# REF_AREA                     0
# Reference area               0
# MEASURE                      0
# Measure                      0
# UNIT_MEASURE                 0
# Unit of measure              0
# SEX                          0
# Sex                          0
# AGE                          0
# Age                          0
# LABOUR_FORCE_STATUS          0
# Labour force status          0
# WORK_PERIOD                  0
# Work period                  0
# HOURS_TYPE                   0
# Hours type                   0
# WORKER_STATUS                0
# Worker status                0
# WORK_TIME_ARNGMNT            0
# Working time arrangement     0
# AGGREGATION_OPERATION        0
# Aggregation operation        0
# HOUR_BANDS                   0
# Hour bands                   0
# JOB_COVERAGE                 0
# Job coverage                 0
# ...

# %%
combined['Time period'] = combined['Time period'].fillna("Unknown")

# %%
combined = combined.dropna(subset=['Time period'])

# %%
combined.head()
# Out:
#   STRUCTURE                                 STRUCTURE_ID  \
# 0  DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 1  DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 2  DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 3  DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
# 4  DATAFLOW  OECD.ELS.SAE:DSD_HW@DF_AVG_ANN_HRS_WKD(1.0)
#
#                                     STRUCTURE_NAME ACTION REF_AREA  \
# 0  Average annual hours actually worked per worker      I      USA
# 1  Average annual hours actually worked per worker      I      USA
# 2  Average annual hours actually worked per worker      I      USA
# 3  Average annual hours actually worked per worker      I      USA
# 4  Average annual hours actually worked per worker      I      USA
#
#   Reference area MEASURE       Measure UNIT_MEASURE  \
# 0  United States      HW  Hours worked       H_Y_PS
# 1  United States      HW  Hours worked       H_Y_PS
# 2  United States      HW  Hours worked       H_Y_PS
# ...

# %%
combined.isnull().sum()
# Out:
# STRUCTURE                    0
# STRUCTURE_ID                 0
# STRUCTURE_NAME               0
# ACTION                       0
# REF_AREA                     0
# Reference area               0
# MEASURE                      0
# Measure                      0
# UNIT_MEASURE                 0
# Unit of measure              0
# SEX                          0
# Sex                          0
# AGE                          0
# Age                          0
# LABOUR_FORCE_STATUS          0
# Labour force status          0
# WORK_PERIOD                  0
# Work period                  0
# HOURS_TYPE                   0
# Hours type                   0
# WORKER_STATUS                0
# Worker status                0
# WORK_TIME_ARNGMNT            0
# Working time arrangement     0
# AGGREGATION_OPERATION        0
# Aggregation operation        0
# HOUR_BANDS                   0
# Hour bands                   0
# JOB_COVERAGE                 0
# Job coverage                 0
# ...

# %%
combined['UNIT_MULT'] = combined['UNIT_MULT'].fillna(combined['Unit multiplier'])
combined['Unit multiplier'] = combined['Unit multiplier'].fillna(combined['UNIT_MULT'])

# %%
combined[['UNIT_MULT', 'Unit multiplier']].isnull().sum()
# Out:
# UNIT_MULT          30
# Unit multiplier    30
# dtype: int64

# %%
combined.isnull().sum()
# Out:
# STRUCTURE                    0
# STRUCTURE_ID                 0
# STRUCTURE_NAME               0
# ACTION                       0
# REF_AREA                     0
# Reference area               0
# MEASURE                      0
# Measure                      0
# UNIT_MEASURE                 0
# Unit of measure              0
# SEX                          0
# Sex                          0
# AGE                          0
# Age                          0
# LABOUR_FORCE_STATUS          0
# Labour force status          0
# WORK_PERIOD                  0
# Work period                  0
# HOURS_TYPE                   0
# Hours type                   0
# WORKER_STATUS                0
# Worker status                0
# WORK_TIME_ARNGMNT            0
# Working time arrangement     0
# AGGREGATION_OPERATION        0
# Aggregation operation        0
# HOUR_BANDS                   0
# Hour bands                   0
# JOB_COVERAGE                 0
# Job coverage                 0
# ...

# %%
combined['UNIT_MULT'] = combined['UNIT_MULT'].fillna(combined['Unit multiplier'])
combined['Unit multiplier'] = combined['Unit multiplier'].fillna(combined['UNIT_MULT'])

# %%
combined[['OBS_VALUE', 'Observation value',
          'OBS_STATUS', 'Observation status',
          'UNIT_MULT', 'Unit multiplier']].isnull().sum()
# Out:
# OBS_VALUE              0
# Observation value     30
# OBS_STATUS             0
# Observation status     0
# UNIT_MULT             30
# Unit multiplier       30
# dtype: int64

# %%
# Overwrite duplicates with the master columns
combined['Observation value'] = combined['OBS_VALUE']
combined['Observation status'] = combined['OBS_STATUS']
combined['Unit multiplier'] = combined['UNIT_MULT']

# %%
combined[['OBS_VALUE', 'Observation value',
          'OBS_STATUS', 'Observation status',
          'UNIT_MULT', 'Unit multiplier']].isnull().sum()
# Out:
# OBS_VALUE              0
# Observation value      0
# OBS_STATUS             0
# Observation status     0
# UNIT_MULT             30
# Unit multiplier       30
# dtype: int64

# %%
combined['UNIT_MULT'] = combined['UNIT_MULT'].fillna(0)
combined['Unit multiplier'] = combined['Unit multiplier'].fillna(0)

# %%
combined[['UNIT_MULT', 'Unit multiplier']].isnull().sum()
# Out:
# UNIT_MULT          0
# Unit multiplier    0
# dtype: int64

# %%
combined.isnull().sum()
# Out:
# STRUCTURE                   0
# STRUCTURE_ID                0
# STRUCTURE_NAME              0
# ACTION                      0
# REF_AREA                    0
# Reference area              0
# MEASURE                     0
# Measure                     0
# UNIT_MEASURE                0
# Unit of measure             0
# SEX                         0
# Sex                         0
# AGE                         0
# Age                         0
# LABOUR_FORCE_STATUS         0
# Labour force status         0
# WORK_PERIOD                 0
# Work period                 0
# HOURS_TYPE                  0
# Hours type                  0
# WORKER_STATUS               0
# Worker status               0
# WORK_TIME_ARNGMNT           0
# Working time arrangement    0
# AGGREGATION_OPERATION       0
# Aggregation operation       0
# HOUR_BANDS                  0
# Hour bands                  0
# JOB_COVERAGE                0
# Job coverage                0
# TIME_PERIOD                 0
# ...

# %%
combined.shape
# Out:
# (30, 41)
